# %%
import random
import matplotlib.pyplot as plt

def rollDice():
    roll = random.randint(0,100)
    return roll

listVals = []
for x in range(0,1000):
    rand = rollDice()
    listVals.append(rand)
    print (rand)
# Out:
# 64
# 32
# 34
# 98
# 33
# 39
# 43
# 73
# 41
# 27
# 46
# 43
# 76
# 99
# 83
# 98
# 23
# 54
# 0
# 86
# 90
# 24
# 57
# 92
# 75
# 26
# 71
# 73
# 16
# 62
# 81
# 97
# 88
# 39
# 87
# 20
# 18
# 38
# 27
# 59
# 44
# 68
# 63
# 36
# 90
# 8
# 75
# 22
# 66
# 93
# 97
# 66
# 6
# 18
# 38
# 44
# 26
# 48
# 10
# 36
# 20
# 69
# 17
# 45
# 84
# 87
# 91
# 17
# 93
# 76
# 90
# 71
# 76
# 80
# 38
# 16
# 92
# 79
# 95
# 35
# 8
# 23
# 45
# 44
# 1
# 54
# 80
# 72
# 60
# 11
# 87
# 64
# 50
# 8
# 52
# 54
# 52
# 20
# 82
# 54
# 23
# 73
# 26
# 54
# 45
# 99
# 31
# 46
# 42
# 4
# 82
# 46
# 79
# 74
# 35
# 50
# 80
# 57
# 20
# 93
# 100
# 66
# 94
# 92
# 50
# 44
# 81
# 17
# 50
# 49
# 100
# 99
# 77
# 71
# 38
# 12
# 13
# 11
# 35
# 59
# 30
# 27
# 9
# 39
# 72
# 15
# 23
# 95
# 34
# 22
# 91
# 94
# 3
# 6
# 51
# 16
# 8
# 56
# 81
# 100
# 10
# 40
# 22
# 51
# 65
# 30
# 94
# 18
# 84
# 53
# 46
# 26
# 49
# 85
# 42
# 93
# 69
# 25
# 47
# 84
# 86
# 2
# 96
# 55
# 52
# 77
# 79
# 75
# 57
# 65
# 87
# 73
# 82
# 7
# 63
# 21
# 40
# 39
# 12
# 73
# 20
# 22
# ...

# %%
print(listVals[0])
l=[]
data=[]
#change end from 10 to 1000
for x in range(0,1000):
    l.append(x)
    data.append(listVals[x])
#[10,20,30,40,50,30,10,10,10,10]
plt.scatter(l,data)
plt.legend()
plt.show()
# Out:
# 64
# /Users/dc/anaconda/envs/3conda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
#frequency test for randomness is frequency of #s the same? 
freq={}
for x in listVals:
    freq.put()

# %%
test='abcdefghij'

dict = {}

for letter in test:
    if dict.get(letter)==None:
        dict[letter] = 1
    else:
        dict[letter]=dict[key]+1

print (dict)
# Out:
# {'b': 1, 'a': 1, 'i': 1, 'e': 1, 'c': 1, 'g': 1, 'f': 1, 'j': 1, 'h': 1, 'd': 1}

# %%
import math
import random
import numpy

const = 1/10*math.sqrt(2*math.pi)
sum=0
for num in range(0,100000):
    if (num<=6 and num>=3):
        y=math.exp(-(num-1.0)**2.0/200.0)
        sum = sum+y
print (sum)
# Out:
# 3.7418094041110868

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats



lower, upper = 3, 6
mu, sigma = 1, 10
X = stats.truncnorm(
    (lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
N = stats.norm(loc=mu, scale=sigma)
for x in range(1,10):
    print(X.rvs(x))

fig, ax = plt.subplots(2, sharex=True)
ax[0].hist(X.rvs(10000), normed=True)
ax[1].hist(N.rvs(10000), normed=True)
plt.show()
# Out:
# [ 4.42414698]
# [ 3.44473548  3.66585285]
# [ 5.46210281  3.23073282  5.27858183]
# [ 4.56617896  5.92762333  3.55391252  4.20785377]
# [ 5.39339763  3.83496249  3.36547636  4.47424296  5.27734345]
# [ 3.91477838  4.52557463  3.03767201  4.71893962  4.24464553  5.96080238]
# [ 5.55209557  5.15098251  3.71826836  4.7632054   4.90527956  5.82382025
#   4.71183914]
# [ 4.98322076  4.72020694  3.66760709  3.30489451  4.58930494  5.71687136
#   4.75896724  3.59370092]
# [ 3.45584168  4.90670277  4.12604138  4.63956706  5.34595949  3.82210481
#   3.28560792  4.92606504  5.35808493]

# %%
#python uniform distribution
import numpy as np
numRuns=100000
x = np.random.uniform(-0.5,0.5,numRuns)
y = np.random.uniform(-0.5,0.5,numRuns)


sum = x**2 + y**2

sumValues = 0
for i in sum:
    if i<=.5**2:
        sumValues +=1
        
print ('sumValues:',sumValues)
print((sumValues/(float)(numRuns))*4.)
# Out:
# sumValues: 78842
# 3.15368

# %%
print (s.shape)
# Out:
# (1000,)
